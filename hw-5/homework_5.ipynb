# %%
import pandas as pd
import numpy as np
from sklearn import datasets
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('DataSet_Lesson31.csv', index_col=0)
data.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  texture_worst  \
# id                                            ...
# ...

# %%
#Базовые статистики датасета

# %%
data.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
print(data.isnull().sum())
# Out:
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# ...

# %%
data.drop(['id', 'Unnamed: 32'], axis=1, inplace=True)

# %%
data['diagnosis'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data['diagnosis'].value_counts(normalize=True)
# Out:
# B    0.627417
# M    0.372583
# Name: diagnosis, dtype: float64

# %%
data['diagnosis'] = data['diagnosis'].apply(lambda x: 1 if x=='M' else 0)

# %%
data['diagnosis'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Постройте гистограммы/распределения признаков, при этом используйте целевую переменную, 
# чтобы сгруппировать и раскрасить гистограммы.

# %%
sns.histplot(data=data, x="radius_mean", hue="diagnosis", multiple="layer", shrink=1)
# Out:
# <AxesSubplot:xlabel='radius_mean', ylabel='Count'>

# %%
sns.histplot(data=data, x="area_mean", hue="diagnosis", multiple="layer", shrink=1)
# Out:
# <AxesSubplot:xlabel='area_mean', ylabel='Count'>

# %%
sns.histplot(data=data, x="concave points_se", hue="diagnosis", multiple="layer", shrink=1)
# Out:
# <AxesSubplot:xlabel='concave points_se', ylabel='Count'>

# %%
# Постройте heatmap для матрицы корреляций, есть ли признаки, которые сильно скоррелированы? Какие это признаки?

# %%
plt.subplots(figsize=(20,20))
sns.heatmap(data.corr(), annot=True, cbar=False, linewidths=1, fmt='.2f')
plt.show()

# %%
# Постройте для сильно скоррелированных признаков попарные scatterplot-ы, 
# действительно ли наблюдается линейная зависимость?

# %%
corrmat = data.corr()
cols = corrmat.nlargest(5, 'diagnosis')['diagnosis'].index.tolist()

max_corr = np.corrcoef(data[cols].values.T)
plt.figure(figsize=(10,10))
sns.heatmap(max_corr, annot=True, linewidths=1, fmt='.2f', yticklabels=cols, xticklabels=cols)
plt.show()

# %%
sns.pairplot(data=data[cols], hue='diagnosis')
plt.show()

# %%
# perimetr_worst - radius_worst линейно зависимы

# %%
# Используя boxplots и группировку по целевой переменной, попробуйте предположить, 
# по каким признакам наиболее удобно было бы отделить злокачественные новообразования от доброкачественных.

# %%
plt.figure(figsize=(5, 5))
sns.boxplot(data=data, x='diagnosis', y="radius_mean")
plt.show()

# %%
# Явное отличие диапазона значений radius_mean при разных значениях diagnosis. Удобно отделять

# %%
plt.figure(figsize=(5, 5))
sns.boxplot(data=data, x='diagnosis', y="area_mean")
plt.show()

# %%
# Явное отличие диапазона значений area_mean при разных значениях diagnosis. Удобно отделять

# %%
plt.figure(figsize=(5, 5))
sns.boxplot(data=data, x='diagnosis', y="fractal_dimension_mean")
plt.show()

# %%
# Пересечение диапазона значений fractal_dimension_mean при разных значениях diagnosis. Не удобно отделять

# %%
plt.figure(figsize=(5, 5))
sns.boxplot(data=data, x='diagnosis', y="smoothness_worst")
plt.show()

# %%
# Присутствует пересечение диапазона значений smoothness_worst при разных значениях diagnosis. 
# Отделять затруднительно

# %% [markdown]
# ## Часть 2

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,roc_curve, auc
from sklearn.model_selection import cross_val_score

data = pd.read_csv('DataSet_Lesson31.csv', index_col=0)
data['diagnosis'] = data['diagnosis'].apply(lambda x: 1 if x=='M' else 0)
data.drop('Unnamed: 32', axis=1, inplace=True)
X = data.drop(['diagnosis'], axis=1)
y = data['diagnosis']

# %% [markdown]
# ### Обучение модели

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.67, random_state = 42, stratify = y)

# %% [markdown]
# ### Стандартизация

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Стандартизация данных необходима, потому что масштабы различных признаков (например, радиус и периметр) 
# могут быть разными, а значит, если их не стандартизировать, то модель может не корректно оценить 
# важность каждого признака и произвести ошибочное предсказание.

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ### Метрики качества

# %%
y_pred = knn.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred))
print('Precision:', precision_score(y_test, y_pred))
print('Recall:', recall_score(y_test, y_pred))
print('F1-score:', f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.9574468085106383
# Precision: 1.0
# Recall: 0.8857142857142857
# F1-score: 0.9393939393939393

# %% [markdown]
# ### График ROC-кривой

# %%
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print('AUC-ROC:', roc_auc)

plt.plot(fpr, tpr, color='darkorange',
         label='ROC кривая (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1])
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.show()
# Out:
# AUC-ROC: 0.9428571428571428

# %% [markdown]
# ### Настройка параметра числа соседей методом кросс-валидации

# %%
k_range = list(range(1, 50))
scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    score = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy')
    scores.append(score.mean())
    
optimal_k = k_range[scores.index(max(scores))]
print("Оптимальное значение числа соседей:", optimal_k)
# Out:
# Оптимальное значение числа соседей: 13

# %%
knn = KNeighborsClassifier(n_neighbors=optimal_k)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %% [markdown]
# ### Метрики качества с оптимальным числом соседей

# %%
y_pred = knn.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred))
print('Precision:', precision_score(y_test, y_pred))
print('Recall:', recall_score(y_test, y_pred))
print('F1-score:', f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.9414893617021277
# Precision: 0.9836065573770492
# Recall: 0.8571428571428571
# F1-score: 0.916030534351145

# %% [markdown]
# ### График ROC-кривой после кросс-валидации

# %%
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print('AUC-ROC:', roc_auc)

plt.plot(fpr, tpr, color='darkorange',
         label='ROC кривая (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1])
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.show()
# Out:
# AUC-ROC: 0.9243341404358354
